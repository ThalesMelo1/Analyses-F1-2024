# %% [markdown]
# Load

# %%
import pandas as pd
import numpy as np
import matplotlib as mt

# %%
DriversDF = pd.read_csv('drivers.csv')
RacesDF = pd.read_csv('races.csv')
ResultsDF = pd.read_csv('results.csv')

# %% [markdown]
# # Separate only the necessary from the data bases

# %% [markdown]
# ## Get only the necessary from drivers.csv

# %%
DriversDF
# Out:
#      driverId   driverRef number code  forename     surname         dob  \
# 0           1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...         ...    ...  ...       ...         ...         ...
# 856       858    sargeant      2  SAR     Logan    Sargeant  2000-12-31
# 857       859      lawson     30  LAW      Liam      Lawson  2002-02-11
# 858       860     bearman     38  BEA    Oliver     Bearman  2005-05-08
# 859       861   colapinto     43  COL    Franco   Colapinto  2003-05-27
# 860       862      doohan     61  DOO      Jack      Doohan  2003-01-20
#
#        nationality                                             url
# ...

# %%
Drivers = DriversDF[['driverId','forename','driverRef']]
Drivers
# Out:
#      driverId  forename   driverRef
# 0           1     Lewis    hamilton
# 1           2      Nick    heidfeld
# 2           3      Nico     rosberg
# 3           4  Fernando      alonso
# 4           5    Heikki  kovalainen
# ..        ...       ...         ...
# 856       858     Logan    sargeant
# 857       859      Liam      lawson
# 858       860    Oliver     bearman
# 859       861    Franco   colapinto
# 860       862      Jack      doohan
#
# [861 rows x 3 columns]

# %% [markdown]
# ## Get only the necessary from races.csv

# %%
RacesDF
# Out:
#       raceId  year  round  circuitId                    name        date  \
# 0          1  2009      1          1   Australian Grand Prix  2009-03-29
# 1          2  2009      2          2    Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17      Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3      Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4      Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                     ...         ...
# 1120    1140  2024     20         32  Mexico City Grand Prix  2024-10-27
# 1121    1141  2024     21         18    São Paulo Grand Prix  2024-11-03
# 1122    1142  2024     22         80    Las Vegas Grand Prix  2024-11-23
# 1123    1143  2024     23         78        Qatar Grand Prix  2024-12-01
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix  2024-12-08
#
#           time                                                url    fp1_date  \
# ...

# %%
Races = RacesDF[['raceId', 'circuitId', 'name', 'date']].sort_values(by='date', ascending = False)
Races
# Out:
#       raceId  circuitId                    name        date
# 1124    1144         24    Abu Dhabi Grand Prix  2024-12-08
# 1123    1143         78        Qatar Grand Prix  2024-12-01
# 1122    1142         80    Las Vegas Grand Prix  2024-11-23
# 1121    1141         18    São Paulo Grand Prix  2024-11-03
# 1120    1140         32  Mexico City Grand Prix  2024-10-27
# ...      ...        ...                     ...         ...
# 836      837         13      Belgian Grand Prix  1950-06-18
# 835      836         66        Swiss Grand Prix  1950-06-04
# 834      835         19        Indianapolis 500  1950-05-30
# 833      834          6       Monaco Grand Prix  1950-05-21
# 832      833          9      British Grand Prix  1950-05-13
#
# [1125 rows x 4 columns]

# %% [markdown]
# ## Get only the necessary from results.csv

# %%
ResultsDF
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26754     26760    1144       825            210     20    14       16
# 26755     26761    1144       859            215     30    12       17
# 26756     26762    1144       822             15     77     9       \N
# 26757     26763    1144       861              3     43    20       \N
# 26758     26764    1144       815              9     11    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
Results = ResultsDF[['raceId', 'driverId', 'position', 'constructorId']]
Results.rename(columns= {'raceId' : 'raceID'}, inplace = True)
Results
# Out:
# /tmp/ipykernel_30874/3261001672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results.rename(columns= {'raceId' : 'raceID'}, inplace = True)
#        raceID  driverId position  constructorId
# 0          18         1        1              1
# 1          18         2        2              2
# 2          18         3        3              3
# 3          18         4        4              4
# 4          18         5        5              1
# ...       ...       ...      ...            ...
# 26754    1144       825       16            210
# 26755    1144       859       17            215
# 26756    1144       822       \N             15
# 26757    1144       861       \N              3
# 26758    1144       815       \N              9
#
# [26759 rows x 4 columns]

# %% [markdown]
# # Combine all of the information

# %%
All = pd.concat([Drivers, Races, Results], axis=1)

# %%
All
# Out:
#        driverId  forename   driverRef  raceId  circuitId  \
# 0           1.0     Lewis    hamilton     1.0        1.0
# 1           2.0      Nick    heidfeld     2.0        2.0
# 2           3.0      Nico     rosberg     3.0       17.0
# 3           4.0  Fernando      alonso     4.0        3.0
# 4           5.0    Heikki  kovalainen     5.0        4.0
# ...         ...       ...         ...     ...        ...
# 26754       NaN       NaN         NaN     NaN        NaN
# 26755       NaN       NaN         NaN     NaN        NaN
# 26756       NaN       NaN         NaN     NaN        NaN
# 26757       NaN       NaN         NaN     NaN        NaN
# 26758       NaN       NaN         NaN     NaN        NaN
#
#                         name        date  raceID  driverId position  \
# 0      Australian Grand Prix  2009-03-29      18         1        1
# 1       Malaysian Grand Prix  2009-04-05      18         2        2
# 2         Chinese Grand Prix  2009-04-19      18         3        3
# ...

# %%
df = pd.DataFrame({
    'categoria': ['A', 'A', 'B', 'B', 'C'],
    'valor': [10, 15, 20, 25, 30]
})

df
# Out:
#   categoria  valor
# 0         A     10
# 1         A     15
# 2         B     20
# 3         B     25
# 4         C     30
